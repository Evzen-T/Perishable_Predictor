# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo26n-seg.pt") #Load pretrain model
results = model.train(data="carparts-seg.yaml", epochs=50, imgsz=640)

# %%
results = model.val()
results = model.predict('./')
